# %%
data = '2 3 0 3 10 11 12 1 1 0 1 99 2 1 1 2'

# %%
dl = data.split(' ')

# %%
dl1 = [int(x) for x in dl]

# %%
# header = data[:2]
metadata = []
def find_metadata(data, metadata=[], rem_meta = 0):
    print('data ', data)
#     rem_child = 0
    header = data[:2]
    num_child = header[0]
    num_meta = header[1]
    if num_child == 0:
        metadata += data[2:2+num_meta]
        print('metadata', metadata)
        find_metadata(data[2+num_meta:])
    elif len(data) == rem_meta:
        metadata += data
    else:
        find_metadata(data)
#             find_metadata(data[2:])
#         except:
#             print('x')
#             metadata += data
    return metadata

# %%
f = find_metadata(dl1)
# Out:
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# data  [2, 3, 0, 3, 10, 11, 12, 1, 1, 0, 1, 99, 2, 1, 1, 2]
# ...

# %%
f, sum(f)
# Out:
# ([10, 11, 12, 99, 1, 2], 135)
